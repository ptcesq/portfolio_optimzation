# %% [markdown]
# ### 017 - Save IBM Quantum Token

# %%
from qiskit_ibm_runtime import QiskitRuntimeService

# %%
# Replace with your real API token from https://quantum.ibm.com
API_TOKEN = "<< TOKEN >>"

# One-time persistent save:
QiskitRuntimeService.save_account(
     channel="ibm_quantum_platform",
     token=API_TOKEN,
     overwrite=True
)
