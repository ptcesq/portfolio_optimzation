# %%
import Quantum_Optim_Funct as qof

# %%
df = qof.get_assets(companies_list=['IBM', 'ACN', 'XOM']) 
df.head()
# Out:
#   Ticker  Last Close  Total Return  Daily Volatility
# 0    IBM  289.700012      0.654483          0.017792
# 1    ACN  295.459991     -0.023434          0.017153
# 2    XOM  109.379997     -0.048539          0.015293
