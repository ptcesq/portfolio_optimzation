# %% [markdown]
# # 012 - QAOA Version 0.01

# %% [markdown]
# #### Solve the binary portfolio selection problem using the Quantum Approximate Optimization Algorithm (QAOA).  This notebook loads the QUBO formulation generated in the classical notebook and solves it using Qiskit.
