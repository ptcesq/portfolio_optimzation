# %% [markdown]
# # 020 - Covariance Analysis

# %% [markdown]
# ## 1.00 Admin

# %% [markdown]
# #### 1.10 Libraries

# %%
from qiskit import (
    QuantumCircuit, 
    transpile,
)
from qiskit_ibm_runtime import (
    Batch,
    SamplerV2,
    QiskitRuntimeService,
)

# for circuit graphics 
import pylatexenc

# for the environment report 
import environment as envir 
from tabulate import tabulate

import yfinance as yf

# %%
data, headers = envir.environment_state()
print(tabulate(data, headers=headers, tablefmt="grid"))
# Out:
# +--------------------+-----------+
# | System/Library     | Version   |
# +====================+===========+
# | Python             | 3.12.1    |
# +--------------------+-----------+
# | numpy              | 2.4.4     |
# +--------------------+-----------+
# | qiskit             | 2.4.1     |
# +--------------------+-----------+
# | qiskit_ibm_runtime | 0.46.1    |
# +--------------------+-----------+
# | pylatexenc         | 2.10      |
# +--------------------+-----------+
# | yfinance           | 1.3.0     |
# +--------------------+-----------+

# %% [markdown]
# ### Create Data

# %%
asset_1 = [10, 15, 20, 10, 5] 
asset_2 = [-10, -15, -20, -10, -5]

# %%
def covariance(alpha, beta): 
    absolute_value = abs(alpha) + abs(beta) 
    print(absolute_value)

    # if the values are equal 
    if abs(alphia) == abs(beta): 
        force = absolute_value 
    else:

# %%
covariance(1, 2)
# Out:
# 3
